# %%
import pyodbc

conn = pyodbc.connect(
    "DRIVER={ODBC Driver 17 for SQL Server};"
    "SERVER=LAPTOP-8J4HGE8R;"
    "DATABASE=AMD_DB;"
    "UID=sa;"
    "PWD=Cache@123"
)
print("Connected!")
# Out:
# Connected!
